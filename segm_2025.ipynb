# %% [markdown]
# **Mines Paris 2025**
#
# Deep Learning for Image Analisis
#
# Practical Session: Oct 21-2025
#
# You should submit the notebook with the answers by email before the deadline.
#
# Deadline: Oct 27-2025
#
# etienne.decenciere@minesparis.psl.eu
#
# Teaching assistants:
#
# leo.dechaumet@minesparis.psl.eu
#
# camille.robin@minesparis.psl.eu

# %% [markdown]
# # Segmentation
#
# In this notebook you will train and test a deep learning model to perform binary image segmentation. Segmentation is a very common tool in image analysis. In particular, binary segmentation is used to locate some particular elements in an image, which will be labeled in white while the rest of the image remains black, like in [this example](https://i.stack.imgur.com/i24FE.png):

# %% [markdown]
# <a href="https://i.sstatic.net/i24FE.png"><img src="https://i.sstatic.net/i24FE.png" title="segmentation"/></div>

# %% [markdown]
# This notebook deals with Whole Slide Images (WSI). Whole slide imaging, also known as virtual microscopy, refers to scanning a complete microscope slide and creating a single high-resolution digital file. For more information, see [this introduction](https://www.mbfbioscience.com/whole-slide-imaging-analysis).

# %%
import os
import json
from datetime import datetime
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.python.keras import backend as K
import imageio.v2 as imageio
import numpy as np
from scipy import ndimage
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Data
#
# Drag and drop the tissue-20221017T082544Z-001.zip into the colab files. Once done run the cell below to unzip the files into the 'data' folder.
#
# Have a look at the different images in the folder, both initial images and their associated binary mask. As you can see some of them are quite messy with dirt, pen marks... The objective of this work is to create a model to segment these WSI images to remove these unwanted details.

# %%
# !unzip tissue.zip -d data
# Out:
# Archive:  tissue.zip
#   inflating: data/tissue/val/.DS_Store
#   inflating: data/tissue/test/.DS_Store
#   inflating: data/tissue/train/.DS_Store
#   inflating: data/tissue/test/lbl/492074.jpg
#   inflating: data/tissue/test/lbl/480874.jpg
#   inflating: data/tissue/test/lbl/500202.jpg
#   inflating: data/tissue/test/lbl/545966.jpg
#   inflating: data/tissue/test/lbl/520051.jpg
#   inflating: data/tissue/test/lbl/574866.jpg
#   inflating: data/tissue/test/lbl/581037.jpg
#   inflating: data/tissue/test/lbl/508023.jpg
#   inflating: data/tissue/test/lbl/520556.jpg
#   inflating: data/tissue/test/lbl/533396.jpg
#   inflating: data/tissue/test/lbl/565522.jpg
#   inflating: data/tissue/test/lbl/83549.jpg
#   inflating: data/tissue/test/lbl/85647.jpg
#   inflating: data/tissue/test/lbl/569254.jpg
#   inflating: data/tissue/test/lbl/488883.jpg
#   inflating: data/tissue/test/lbl/579843.jpg
#   inflating: data/tissue/test/lbl/542401.jpg
#   inflating: data/tissue/test/lbl/82487.jpg
#   inflating: data/tissue/test/lbl/526249.jpg
#   inflating: data/tissue/test/lbl/538955.jpg
#   inflating: data/tissue/test/lbl/495534.jpg
#   inflating: data/tissue/test/lbl/475277.jpg
#   inflating: data/tissue/test/lbl/482789.jpg
#   inflating: data/tissue/test/lbl/578812.jpg
#   inflating: data/tissue/test/lbl/504092.jpg
#   inflating: data/tissue/test/lbl/526806.jpg
#   inflating: data/tissue/test/lbl/563514.jpg
#   inflating: data/tissue/test/lbl/552576.jpg
#   inflating: data/tissue/test/lbl/582838.jpg
#   inflating: data/tissue/test/lbl/522148.jpg
#   inflating: data/tissue/test/lbl/492548.jpg
#   inflating: data/tissue/test/lbl/533717.jpg
#   inflating: data/tissue/test/lbl/563919.jpg
#   inflating: data/tissue/test/lbl/521334.jpg
#   inflating: data/tissue/test/jpg/504092.jpg
#   inflating: data/tissue/test/lbl/565153.jpg
#   inflating: data/tissue/test/jpg/492074.jpg
#   inflating: data/tissue/test/lbl/504179.jpg
#   inflating: data/tissue/test/jpg/520051.jpg
#   inflating: data/tissue/test/jpg/82487.jpg
#   inflating: data/tissue/test/lbl/520050.jpg
#   inflating: data/tissue/test/jpg/574866.jpg
#   inflating: data/tissue/test/jpg/520556.jpg
#   inflating: data/tissue/test/jpg/500202.jpg
#   inflating: data/tissue/test/lbl/551955.jpg
#   inflating: data/tissue/test/jpg/551955.jpg
#   inflating: data/tissue/test/lbl/578578.jpg
#   inflating: data/tissue/test/jpg/581037.jpg
#   inflating: data/tissue/test/jpg/545966.jpg
#   inflating: data/tissue/test/jpg/508023.jpg
#   inflating: data/tissue/test/jpg/482789.jpg
#   inflating: data/tissue/test/jpg/504179.jpg
#   inflating: data/tissue/test/jpg/480874.jpg
#   inflating: data/tissue/test/jpg/85647.jpg
#   inflating: data/tissue/test/jpg/495534.jpg
#   inflating: data/tissue/test/jpg/563514.jpg
#   inflating: data/tissue/test/jpg/578812.jpg
#   inflating: data/tissue/test/jpg/522148.jpg
#   inflating: data/tissue/test/jpg/533396.jpg
#   inflating: data/tissue/test/jpg/542401.jpg
#   inflating: data/tissue/test/jpg/538955.jpg
#   inflating: data/tissue/test/jpg/526249.jpg
#   inflating: data/tissue/test/lbl/533901.jpg
#   inflating: data/tissue/test/jpg/579843.jpg
#   inflating: data/tissue/test/jpg/492548.jpg
#   inflating: data/tissue/test/jpg/565153.jpg
#   inflating: data/tissue/test/jpg/475277.jpg
#   inflating: data/tissue/test/jpg/526806.jpg
#   inflating: data/tissue/test/jpg/488883.jpg
#   inflating: data/tissue/test/jpg/83549.jpg
#   inflating: data/tissue/test/lbl/576041.jpg
#   inflating: data/tissue/test/jpg/578578.jpg
#   inflating: data/tissue/test/jpg/533901.jpg
#   inflating: data/tissue/val/jpg/509709.jpg
#   inflating: data/tissue/test/jpg/533717.jpg
#   inflating: data/tissue/test/jpg/582838.jpg
#   inflating: data/tissue/test/jpg/520050.jpg
#   inflating: data/tissue/test/jpg/565522.jpg
#   inflating: data/tissue/test/jpg/563919.jpg
#   inflating: data/tissue/val/jpg/530171.jpg
#   inflating: data/tissue/val/jpg/547529.jpg
#   inflating: data/tissue/test/jpg/576041.jpg
#   inflating: data/tissue/test/jpg/551429.jpg
#   inflating: data/tissue/test/jpg/552576.jpg
#   inflating: data/tissue/val/jpg/575370.jpg
#   inflating: data/tissue/val/jpg/496386.jpg
#   inflating: data/tissue/val/jpg/548658.jpg
#   inflating: data/tissue/val/jpg/564121.jpg
#   inflating: data/tissue/val/jpg/485889.jpg
#   inflating: data/tissue/test/lbl/551429.jpg
#   inflating: data/tissue/val/jpg/489350.jpg
#   inflating: data/tissue/val/jpg/481545.jpg
#   inflating: data/tissue/val/jpg/541161.jpg
#   inflating: data/tissue/val/jpg/537731.jpg
#   inflating: data/tissue/val/jpg/574527.jpg
#   inflating: data/tissue/val/jpg/472117.jpg
#   inflating: data/tissue/val/jpg/581496.jpg
#   inflating: data/tissue/val/jpg/479160.jpg
#   inflating: data/tissue/val/jpg/51176.jpg
#   inflating: data/tissue/val/jpg/544161.jpg
#   inflating: data/tissue/val/jpg/565420.jpg
#   inflating: data/tissue/val/jpg/575825.jpg
#   inflating: data/tissue/val/jpg/531934.jpg
#   inflating: data/tissue/val/jpg/568552.jpg
#   inflating: data/tissue/val/jpg/533668.jpg
#   inflating: data/tissue/val/jpg/572115.jpg
#   inflating: data/tissue/val/jpg/523864.jpg
#   inflating: data/tissue/train/lbl/555029.jpg
#   inflating: data/tissue/val/jpg/484384.jpg
#   inflating: data/tissue/val/jpg/529923.jpg
#   inflating: data/tissue/train/lbl/577123.jpg
#   inflating: data/tissue/train/lbl/486274.jpg
#   inflating: data/tissue/train/lbl/564313.jpg
#   inflating: data/tissue/train/lbl/488297.jpg
#   inflating: data/tissue/train/lbl/564574.jpg
#   inflating: data/tissue/test/jpg/484905.jpg
#   inflating: data/tissue/train/lbl/552360.jpg
#   inflating: data/tissue/train/lbl/500791.jpg
#   inflating: data/tissue/train/lbl/579673.jpg
#   inflating: data/tissue/train/lbl/475696.jpg
#   inflating: data/tissue/train/lbl/490725.jpg
#   inflating: data/tissue/train/lbl/564023.jpg
#   inflating: data/tissue/train/lbl/556426.jpg
#   inflating: data/tissue/train/lbl/581910.jpg
#   inflating: data/tissue/train/lbl/486340.jpg
#   inflating: data/tissue/train/lbl/582632.jpg
#   inflating: data/tissue/test/lbl/484905.jpg
#   inflating: data/tissue/train/lbl/510171.jpg
#   inflating: data/tissue/train/lbl/508389.jpg
#   inflating: data/tissue/train/lbl/495673.jpg
#   inflating: data/tissue/val/jpg/548657.jpg
#   inflating: data/tissue/train/lbl/471752.jpg
#   inflating: data/tissue/train/lbl/528301.jpg
#   inflating: data/tissue/train/lbl/566981.jpg
#   inflating: data/tissue/train/lbl/542065.jpg
#   inflating: data/tissue/val/jpg/44565.jpg
#   inflating: data/tissue/test/jpg/569254.jpg
#   inflating: data/tissue/train/lbl/539291.jpg
#   inflating: data/tissue/train/lbl/585452.jpg
#   inflating: data/tissue/train/lbl/544865.jpg
#   inflating: data/tissue/test/jpg/521334.jpg
#   inflating: data/tissue/train/lbl/498078.jpg
#   inflating: data/tissue/train/lbl/474105.jpg
#   inflating: data/tissue/train/lbl/586746.jpg
#   inflating: data/tissue/train/lbl/522438.jpg
#   inflating: data/tissue/train/lbl/512388.jpg
#   inflating: data/tissue/train/lbl/558781.jpg
#   inflating: data/tissue/train/lbl/517535.jpg
#   inflating: data/tissue/val/jpg/540915.jpg
#   inflating: data/tissue/train/lbl/521566.jpg
#   inflating: data/tissue/train/lbl/.DS_Store
#   inflating: data/tissue/train/lbl/537757.jpg
#   inflating: data/tissue/train/lbl/536783.jpg
#   inflating: data/tissue/train/lbl/534477.jpg
#   inflating: data/tissue/train/lbl/517314.jpg
#   inflating: data/tissue/train/lbl/497759.jpg
#   inflating: data/tissue/train/lbl/475797.jpg
#   inflating: data/tissue/train/lbl/570101.jpg
#   inflating: data/tissue/train/lbl/487588.jpg
#   inflating: data/tissue/train/lbl/491553.jpg
#   inflating: data/tissue/train/lbl/492222.jpg
#   inflating: data/tissue/train/lbl/569578.jpg
#   inflating: data/tissue/train/lbl/477944.jpg
#   inflating: data/tissue/train/lbl/565282.jpg
#   inflating: data/tissue/train/lbl/577489.jpg
#   inflating: data/tissue/train/lbl/500169.jpg
#   inflating: data/tissue/train/lbl/550877.jpg
#   inflating: data/tissue/train/lbl/543769.jpg
#   inflating: data/tissue/train/lbl/542213.jpg
#   inflating: data/tissue/train/lbl/643524.jpg
#   inflating: data/tissue/train/lbl/546918.jpg
#   inflating: data/tissue/train/lbl/583123.jpg
#   inflating: data/tissue/train/lbl/542542.jpg
#   inflating: data/tissue/train/lbl/38472.jpg
#   inflating: data/tissue/train/jpg/577123.jpg
#   inflating: data/tissue/train/lbl/477756.jpg
#   inflating: data/tissue/train/lbl/1976.jpg
#   inflating: data/tissue/train/lbl/562522.jpg
#   inflating: data/tissue/train/lbl/521968.jpg
#   inflating: data/tissue/train/jpg/581910.jpg
#   inflating: data/tissue/train/lbl/475401.jpg
#   inflating: data/tissue/train/lbl/565677.jpg
#   inflating: data/tissue/train/jpg/564574.jpg
#   inflating: data/tissue/train/lbl/485750.jpg
#   inflating: data/tissue/train/jpg/585452.jpg
#   inflating: data/tissue/train/lbl/579792.jpg
#   inflating: data/tissue/train/lbl/535797.jpg
#   inflating: data/tissue/train/lbl/532144.jpg
#   inflating: data/tissue/train/jpg/552360.jpg
#   inflating: data/tissue/train/jpg/486274.jpg
#   inflating: data/tissue/val/jpg/552898.jpg
#   inflating: data/tissue/val/jpg/588626.jpg
#   inflating: data/tissue/train/lbl/547752.jpg
#   inflating: data/tissue/train/lbl/582152.jpg
#   inflating: data/tissue/train/lbl/566694.jpg
#   inflating: data/tissue/train/lbl/548740.jpg
#   inflating: data/tissue/train/jpg/488297.jpg
#   inflating: data/tissue/train/lbl/491656.jpg
#   inflating: data/tissue/train/lbl/536266.jpg
#   inflating: data/tissue/val/jpg/489524.jpg
#   inflating: data/tissue/val/jpg/538028.jpg
#   inflating: data/tissue/val/jpg/61745.jpg
#   inflating: data/tissue/train/jpg/555029.jpg
#   inflating: data/tissue/train/lbl/586375.jpg
#   inflating: data/tissue/train/jpg/564313.jpg
#   inflating: data/tissue/val/jpg/524646.jpg
#   inflating: data/tissue/val/jpg/517793.jpg
#   inflating: data/tissue/val/jpg/548229.jpg
#   inflating: data/tissue/train/jpg/490725.jpg
#   inflating: data/tissue/val/jpg/577464.jpg
#   inflating: data/tissue/train/jpg/495673.jpg
#   inflating: data/tissue/train/jpg/475401.jpg
#   inflating: data/tissue/train/jpg/579673.jpg
#   inflating: data/tissue/train/lbl/544361.jpg
#   inflating: data/tissue/val/jpg/515868.jpg
#   inflating: data/tissue/val/jpg/492379.jpg
#   inflating: data/tissue/train/jpg/471752.jpg
#   inflating: data/tissue/train/lbl/504298.jpg
#   inflating: data/tissue/train/lbl/572123.jpg
#   inflating: data/tissue/train/lbl/498959.jpg
#   inflating: data/tissue/train/lbl/534854.jpg
#   inflating: data/tissue/train/jpg/556426.jpg
#   inflating: data/tissue/train/jpg/544865.jpg
#   inflating: data/tissue/val/jpg/575813.jpg
#   inflating: data/tissue/train/lbl/539972.jpg
#   inflating: data/tissue/train/jpg/500791.jpg
#   inflating: data/tissue/train/jpg/522438.jpg
#   inflating: data/tissue/train/lbl/562047.jpg
#   inflating: data/tissue/train/jpg/486340.jpg
#   inflating: data/tissue/train/jpg/475696.jpg
#   inflating: data/tissue/train/lbl/504273.jpg
#   inflating: data/tissue/val/jpg/574967.jpg
#   inflating: data/tissue/train/jpg/508389.jpg
#   inflating: data/tissue/train/lbl/481723.jpg
#   inflating: data/tissue/train/lbl/37597.jpg
#   inflating: data/tissue/train/lbl/507934.jpg
#   inflating: data/tissue/train/jpg/498078.jpg
#   inflating: data/tissue/train/lbl/565330.jpg
#   inflating: data/tissue/train/lbl/509892.jpg
#   inflating: data/tissue/train/jpg/544361.jpg
#   inflating: data/tissue/train/lbl/551072.jpg
#   inflating: data/tissue/train/lbl/502182.jpg
#   inflating: data/tissue/train/lbl/558681.jpg
#   inflating: data/tissue/train/lbl/486035.jpg
#   inflating: data/tissue/train/jpg/534477.jpg
#   inflating: data/tissue/train/lbl/578596.jpg
#   inflating: data/tissue/train/lbl/582903.jpg
#   inflating: data/tissue/train/jpg/517535.jpg
#   inflating: data/tissue/train/lbl/531260.jpg
#   inflating: data/tissue/train/lbl/585262.jpg
#   inflating: data/tissue/train/jpg/582632.jpg
#   inflating: data/tissue/train/jpg/536783.jpg
#   inflating: data/tissue/train/jpg/510171.jpg
#   inflating: data/tissue/train/lbl/575420.jpg
#   inflating: data/tissue/train/jpg/539291.jpg
#   inflating: data/tissue/train/jpg/542065.jpg
#   inflating: data/tissue/train/jpg/512388.jpg
#   inflating: data/tissue/train/jpg/586746.jpg
#   inflating: data/tissue/train/jpg/569578.jpg
#   inflating: data/tissue/train/jpg/577489.jpg
#   inflating: data/tissue/train/jpg/475797.jpg
#   inflating: data/tissue/train/jpg/566981.jpg
#   inflating: data/tissue/train/jpg/492222.jpg
#   inflating: data/tissue/train/jpg/566694.jpg
#   inflating: data/tissue/train/lbl/17997.jpg
#   inflating: data/tissue/train/jpg/500169.jpg
#   inflating: data/tissue/train/jpg/535797.jpg
#   inflating: data/tissue/train/jpg/531260.jpg
#   inflating: data/tissue/train/jpg/643524.jpg
#   inflating: data/tissue/train/jpg/521566.jpg
#   inflating: data/tissue/train/jpg/565282.jpg
#   inflating: data/tissue/train/jpg/570101.jpg
#   inflating: data/tissue/train/jpg/558781.jpg
#   inflating: data/tissue/train/jpg/543769.jpg
#   inflating: data/tissue/train/jpg/528301.jpg
#   inflating: data/tissue/train/jpg/487588.jpg
#   inflating: data/tissue/train/jpg/542213.jpg
#   inflating: data/tissue/train/jpg/537757.jpg
#   inflating: data/tissue/train/jpg/38472.jpg
#   inflating: data/tissue/train/lbl/543691.jpg
#   inflating: data/tissue/train/jpg/497759.jpg
#   inflating: data/tissue/train/jpg/543691.jpg
#   inflating: data/tissue/train/jpg/542542.jpg
#   inflating: data/tissue/train/jpg/1976.jpg
#   inflating: data/tissue/train/jpg/541561.jpg
#   inflating: data/tissue/train/jpg/477756.jpg
#   inflating: data/tissue/train/jpg/517314.jpg
#   inflating: data/tissue/train/jpg/477944.jpg
#   inflating: data/tissue/train/jpg/491553.jpg
#   inflating: data/tissue/train/jpg/583123.jpg
#   inflating: data/tissue/train/jpg/474105.jpg
#   inflating: data/tissue/train/jpg/562522.jpg
#   inflating: data/tissue/train/jpg/491656.jpg
#   inflating: data/tissue/train/jpg/504273.jpg
#   inflating: data/tissue/train/jpg/582152.jpg
#   inflating: data/tissue/train/jpg/579792.jpg
#   inflating: data/tissue/train/jpg/586375.jpg
#   inflating: data/tissue/train/jpg/550877.jpg
#   inflating: data/tissue/train/jpg/562047.jpg
#   inflating: data/tissue/train/jpg/585262.jpg
#   inflating: data/tissue/train/jpg/481723.jpg
#   inflating: data/tissue/train/jpg/548740.jpg
#   inflating: data/tissue/train/jpg/37597.jpg
#   inflating: data/tissue/train/jpg/507934.jpg
#   inflating: data/tissue/train/jpg/576122.jpg
#   inflating: data/tissue/train/jpg/521968.jpg
#   inflating: data/tissue/val/jpg/61950.jpg
#   inflating: data/tissue/train/jpg/509892.jpg
#   inflating: data/tissue/train/lbl/541561.jpg
#   inflating: data/tissue/train/jpg/547752.jpg
#   inflating: data/tissue/train/jpg/534854.jpg
#   inflating: data/tissue/train/jpg/504298.jpg
#   inflating: data/tissue/train/jpg/532144.jpg
#   inflating: data/tissue/train/jpg/572123.jpg
#   inflating: data/tissue/train/jpg/498959.jpg
#   inflating: data/tissue/train/jpg/575420.jpg
#   inflating: data/tissue/train/jpg/558681.jpg
#   inflating: data/tissue/train/jpg/578596.jpg
#   inflating: data/tissue/train/jpg/485750.jpg
#   inflating: data/tissue/train/jpg/539972.jpg
#   inflating: data/tissue/train/jpg/565330.jpg
#   inflating: data/tissue/train/jpg/536266.jpg
#   inflating: data/tissue/train/jpg/486035.jpg
#   inflating: data/tissue/train/jpg/473885.jpg
#   inflating: data/tissue/train/jpg/564023.jpg
#   inflating: data/tissue/train/jpg/582903.jpg
#   inflating: data/tissue/train/jpg/502182.jpg
#   inflating: data/tissue/train/jpg/17997.jpg
#   inflating: data/tissue/train/lbl/473885.jpg
#   inflating: data/tissue/train/jpg/565677.jpg
#   inflating: data/tissue/train/jpg/546918.jpg
#   inflating: data/tissue/train/jpg/551072.jpg
#   inflating: data/tissue/val/lbl/531934.jpg
#   inflating: data/tissue/val/lbl/538028.jpg
#   inflating: data/tissue/val/lbl/479160.jpg
#   inflating: data/tissue/val/lbl/537731.jpg
#   inflating: data/tissue/val/lbl/530171.jpg
#   inflating: data/tissue/val/lbl/574527.jpg
#   inflating: data/tissue/val/lbl/572115.jpg
#   inflating: data/tissue/val/lbl/509709.jpg
#   inflating: data/tissue/val/lbl/547529.jpg
#   inflating: data/tissue/val/lbl/481545.jpg
#   inflating: data/tissue/val/lbl/541161.jpg
#   inflating: data/tissue/val/lbl/575825.jpg
#   inflating: data/tissue/val/lbl/472117.jpg
#   inflating: data/tissue/val/lbl/568552.jpg
#   inflating: data/tissue/val/lbl/51176.jpg
#   inflating: data/tissue/val/lbl/564121.jpg
#   inflating: data/tissue/val/lbl/548658.jpg
#   inflating: data/tissue/val/lbl/575370.jpg
#   inflating: data/tissue/val/lbl/565420.jpg
#   inflating: data/tissue/val/lbl/548657.jpg
#   inflating: data/tissue/val/lbl/485889.jpg
#   inflating: data/tissue/val/lbl/544161.jpg
#   inflating: data/tissue/val/lbl/581496.jpg
#   inflating: data/tissue/val/lbl/529923.jpg
#   inflating: data/tissue/val/lbl/489350.jpg
#   inflating: data/tissue/val/lbl/588626.jpg
#   inflating: data/tissue/val/lbl/523864.jpg
#   inflating: data/tissue/val/lbl/524646.jpg
#   inflating: data/tissue/val/lbl/540915.jpg
#   inflating: data/tissue/val/lbl/44565.jpg
#   inflating: data/tissue/val/lbl/533668.jpg
#   inflating: data/tissue/val/lbl/574967.jpg
#   inflating: data/tissue/val/lbl/517793.jpg
#   inflating: data/tissue/val/lbl/484384.jpg
#   inflating: data/tissue/val/lbl/515868.jpg
#   inflating: data/tissue/val/lbl/489524.jpg
#   inflating: data/tissue/val/lbl/492379.jpg
#   inflating: data/tissue/val/lbl/548229.jpg
#   inflating: data/tissue/val/lbl/552898.jpg
#   inflating: data/tissue/val/lbl/61745.jpg
#   inflating: data/tissue/val/lbl/61950.jpg
#   inflating: data/tissue/val/lbl/496386.jpg
#   inflating: data/tissue/val/lbl/577464.jpg
#   inflating: data/tissue/val/lbl/575813.jpg
#   inflating: data/tissue/train/lbl/576122.jpg

# %% [markdown]
# # Fetching data
#
# First step is to implement functions to send data to the training and testing pipeline. To do so, we implement the class DataGeneratorTissue used to select patches of images by customising keras DataGenerator class.
#
# The function `get_random_patch_coord` randomly selects the coordinates of an image's patch, or crop. A `patch_coord` point to the top left corner of the corresponding patch. Thus the coordinates [y, x] gives for a patch of size [h, w] the image's patch *image* [y:y+h, x:x+w].
#
#
# The function `choose_patch_coord` calls `get_random_patch_coord` and should return the coordinates of a patch with at most 70% of background labels (pixel value of 0 in label). If it cannot be achieved after 10 tryouts, the function should return the coordinates of the patch with the lowest background labels found.
#
# The original Ground Truth label in the dataset is a binary image (single channel).
#
# In this notebook, we want to use 2-channel label - the first channel represents the background, while the second one is the foreground, containing the objects of interest (the original binary label image).

# %%
class DataGeneratorTissue(keras.utils.Sequence):

    def __init__(self, path, prefix, batch_size,
                 patch_size, nb_channels_in=3, nb_channels_out=2,
                 geometric_augmentations=[], augmentation_ratio=None):

        self.path = path
        self.prefix = prefix
        self.get_data_dict()
        self.batch_size = batch_size
        self.patch_size = patch_size
        self.nb_channels_in = nb_channels_in
        self.nb_channels_out = nb_channels_out
        self.geometric_augmentations = []
        self.augmentation_ratio = augmentation_ratio

        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.data) / self.batch_size))

    def __getitem__(self, batch_idx):
        batch_data_idxs = self.data_idxs[batch_idx*self.batch_size:(batch_idx+1)*self.batch_size]
        x, y = self.fetch_data(batch_data_idxs)
        return x, y

    def on_epoch_end(self):
        self.data_idxs = np.arange(len(self.data))
        np.random.shuffle(self.data_idxs)

    def get_data_dict(self):
        self.data = {}
        for data_idx, image_name in enumerate(os.listdir(os.path.join(*[self.path, self.prefix, "jpg"]))):
            self.data[data_idx] = image_name

    def get_random_patch_coord(self, image_size):
        '''
        image_size: (height, width)
        '''

        ### TO BE IMPLEMENTED ### (hint: use np.random.randint)
        patch_h, patch_w = self.patch_size
        max_y = image_size[0] - patch_h
        max_x = image_size[1] - patch_w
        y = np.random.randint(0, max_y + 1)
        x = np.random.randint(0, max_x + 1)
        patch_coord = [y, x]
        #########################

        return patch_coord

    def choose_patch_coord(self, image_shape, label, threshold=0.7):
        '''
        image_shape: (height, width)
        label: shape (height, width, channels)
        '''

        ### TO BE IMPLEMENTED ###
        patch_h, patch_w = self.patch_size
        best_bg_fraction = 1.0
        best_patch_coord = self.get_random_patch_coord(image_shape)  # initialize with a random patch

        for _ in range(10):
            coord = self.get_random_patch_coord(image_shape)
            y, x = coord
            label_patch = label[y:y + patch_h, x:x + patch_w, 0]
            bg_fraction = np.sum(label_patch == 0) / (patch_h * patch_w)

            if bg_fraction <= threshold:
                return coord

            if bg_fraction < best_bg_fraction:
                best_bg_fraction = bg_fraction
                best_patch_coord = coord
        #########################

        return best_patch_coord

    def fetch_data(self, batch_data_idxs):
        x = np.empty([self.batch_size, *self.patch_size, self.nb_channels_in])
        y = np.empty([self.batch_size, *self.patch_size, self.nb_channels_out])

        for idx, data_idx in enumerate(batch_data_idxs):
            image_file_path = os.path.join(*[self.path, self.prefix, "jpg", self.data[data_idx]])
            image = imageio.imread(image_file_path)

            label_file_path = os.path.join(*[self.path, self.prefix, "lbl", self.data[data_idx]])
            label = imageio.imread(label_file_path)

            image = np.float32(image/255)
            label = np.expand_dims(np.float32(label/255), axis=-1)

            patch_coord = self.choose_patch_coord(list(image.shape[:2]), label)

            image_patch = image[patch_coord[0]:patch_coord[0]+self.patch_size[0],
                                patch_coord[1]:patch_coord[1]+self.patch_size[1],:]

            label_patch = np.empty([*self.patch_size, 2])
            original_label = label[patch_coord[0]:patch_coord[0]+self.patch_size[0],
                                patch_coord[1]:patch_coord[1]+self.patch_size[1], 0]


            ### TO BE IMPLEMENTED ###
            label_patch[:, :, 0] = (original_label == 0).astype(np.float32)                 # background
            label_patch[:, :, 1] = (original_label == 1).astype(np.float32)                # foreground

            #########################

            if len(self.geometric_augmentations) != 0:
                if np.random.binomial(1, self.augmentation_ratio) == 1:
                    augm_idx = random.randint(0,len(self.geometric_augmentations)-1)
                    image_patch, label_patch = self.geometric_augmentations[augm_idx](image_patch, label_patch)

            x[idx:idx+1,...] = image_patch
            y[idx:idx+1,...] = label_patch

        return x, y

# %% [markdown]
# The following code tests whether your DataGeneratorTissue class works properly. Try running it several times to check that all patches are different, have the correct dimensions, and that the labels are correctly generated.

# %%
path = "data/tissue"
batch_size=1
patch_size = [128, 128]
nb_channels_out =2
val_datagen = DataGeneratorTissue(path, "val", batch_size,
                                  patch_size, 3, nb_channels_out)

data = val_datagen[0]

plt.title("input image")
plt.imshow(data[0][0,:,:])
plt.show()
plt.title("background")
plt.imshow(data[1][0,:,:,0], cmap="gray")
plt.show()
plt.title("tissue")
plt.imshow(data[1][0,:,:,1], cmap="gray")
plt.show()

# %% [markdown]
# # UNet model builder
#
# The deep learning model we will use is a U-Net model, which was initially introduced to perform segmentation on microscopy images (see [paper](https://arxiv.org/abs/1505.04597)).
#
# Implement the encoder and decoder parts of the UNet model with skip connections in the `build_unet_model` function using only `conv_block`, `keras.layers.MaxPooling2D`,`up_sampler` and [`keras.layers.Concatenate`](https://keras.io/api/layers/merging_layers/concatenate/) functions.
#
# There are several ways of implementing this in Keras, here we will use what is called the [Functional API](https://keras.io/api/models/model/). The idea is to start from a *template input*, `keras.Input(shape=(..))`, and to define all the transformations this *input* undergoes. These transformations need to be implemented in the form of `keras` or  `tensorflow` chains of transformations (they are already implemented below).
#
# Once done, the model is build implicitely by wrapping the  `inputs` and `outputs` inside a `keras.Model`

# %%
def build_very_simple_model(nb_channels_in,
                            nb_channels_out,
                            unet_filters,
                            image_size=[None, None]):

    inputs = keras.Input([*image_size, nb_channels_in])

    x = keras.layers.Conv2D(filters=256,
                            kernel_size=3,
                            strides=1,
                            padding='same',
                            kernel_initializer='he_normal')(inputs)
    x = keras.layers.ReLU()(x)

    x = keras.layers.Conv2D(filters=1,
                                kernel_size=3,
                                strides=1,
                                padding='same',
                                kernel_initializer='he_normal')(x)
    outputs = tf.math.sigmoid(x)

    model = keras.Model(inputs, outputs)

    return model

# %%
def conv_block(filters, strides):
    conv_block = keras.Sequential([keras.layers.Conv2D(filters=filters, kernel_size=3,
                                                        strides=1, padding="same",
                                                        kernel_initializer = "he_normal"),
                                    keras.layers.BatchNormalization(),
                                    keras.layers.LeakyReLU(),
                                    keras.layers.Conv2D(filters=filters, kernel_size=3,
                                                        strides=strides, padding="same",
                                                        kernel_initializer = "he_normal"),
                                    keras.layers.BatchNormalization(),
                                    keras.layers.LeakyReLU()])
    return conv_block

def final_block(filters, last_activation):
    conv_block = keras.Sequential([keras.layers.Conv2D(filters=filters, kernel_size=3,
                                                        strides=1, padding="same",
                                                        kernel_initializer = "he_normal"),
                                    keras.layers.BatchNormalization(),
                                    keras.layers.Activation(last_activation)])
    return conv_block

def up_sampler(filters):
    up_sampler = keras.Sequential([keras.layers.Conv2DTranspose(filters=filters, kernel_size=2,
                                                                strides=2, padding="valid",
                                                                kernel_initializer = "he_normal"),
                                   keras.layers.BatchNormalization(),
                                   keras.layers.LeakyReLU()])
    return up_sampler

def build_unet_model(nb_channels_in, nb_channels_out,
                     unet_filters, last_activation,
                     image_size=[None, None]):
    inputs = keras.Input([*image_size, nb_channels_in])

    skip = []

    ### TO BE IMPLEMENTED ###
    x = inputs

    # Encoder part
    for filters in unet_filters:
        x = conv_block(filters, strides=1)(x)
        skip.append(x)
        x = keras.layers.MaxPooling2D(pool_size=2)(x)

    # Bottleneck
    x = conv_block(unet_filters[-1] * 2, strides=1)(x)

    # Decoder part
    for filters, skip_connection in zip(reversed(unet_filters), reversed(skip)):
        x = up_sampler(filters)(x)
        x = keras.layers.Concatenate()([x, skip_connection])
        x = conv_block(filters, strides=1)(x)

    #########################


    outputs = final_block(nb_channels_out, last_activation)(x)

    unet_model = keras.Model(inputs, outputs)
    return unet_model

# %% [markdown]
# # Segmentation loss
#
# The loss used here is the Jaccard loss, also known as Intersection over Union. As we are working with binary images as outputs, we want to maximize the overlap area of ground truth and predicted masks (see [Wikipedia](https://fr.wikipedia.org/wiki/Indice_et_distance_de_Jaccard) for more details).
#
# Implement the computation of the cardinal of the intersection and the union between *y_true* and *y_pred*, stored in the variables *intersection* and *union* for the jaccard index-based loss. The function *K.sum()* should be sufficient to do so.

# %%
def jaccard_loss(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    ### TO BE IMPLEMENTED ###
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection

    #########################

    return 1 - (intersection + smooth) / (union + smooth)

# %% [markdown]
# # Data augmentation
#
# Data augmentation enables to generate new elements for our data set by applying some basic transformations to our images. For more examples, see [this tutorial](https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/).

# %%
def flip_aug(image, label):
    flipped_image = np.flip(image, axis=1)
    flipped_label = np.flip(label, axis=1)
    return flipped_image, flipped_label

def rot_aug(image, label):
    image_rotation = ndimage.rotate(image, angle=random.randint(low=-20, high=20))
    label_rotation = ndimage.rotate(label, angle=random.randint(low=-20, high=20))
    return image_rotation, label_rotation

# %% [markdown]
# # Model's training
#
# Launch the training of a UNet with the given hyperparameters on the gpu "gpu:/0" (the first gpu visible by cuda).
# A directory named "models", where are located the models' directories storing the data of the differents models trained, will be created. .
# In a model's directory, named according the model's id and the timestamp of its training (a security to avoid accidental overwriting), are stored the *model_parameters.json*, *best_model_weights.weights.h5* and *log.csv* files.
# Nothing to implement, just run for training.

# %%
path = "data/tissue"

models_dir = "models"
if os.path.exists(models_dir) == False:
    os.mkdir(models_dir)

model_id = 1

dt = datetime.now()
timestamp = str(dt.hour) + ':' + str(dt.minute) + ':' + str(dt.second) + '-' + str(dt.day) + ':' + str(dt.month) + ':' + str(dt.year)
model_name = "modelID=" + str(model_id) +  "_timestamp=" + timestamp

model_dir = os.path.join(models_dir, model_name)
if os.path.exists(model_dir) == False:
    os.mkdir(model_dir)

nb_channels_in = 3
nb_channels_out = 2
last_activation = "softmax"
unet_filters = [8, 16, 32, 64]
patch_size = [128, 128]
batch_size = 5
lr = 0.001
nb_epochs = 50

model_parameters = {"nb_channels_in": nb_channels_in,
                    "nb_channels_out": nb_channels_out,
                    "last_activation": last_activation,
                    "unet_filters": unet_filters,
                    "patch_size": patch_size,
                    "batch_size": batch_size,
                    "lr": lr,
                    "nb_epochs": nb_epochs}

json.dump(model_parameters, open(os.path.join(model_dir, "model_parameters.json"), "w"))

model = build_unet_model(nb_channels_in, nb_channels_out, unet_filters, last_activation , image_size = patch_size)
model.summary()

train_datagen = DataGeneratorTissue(path, "train", batch_size,
                                    patch_size, 3, nb_channels_out,
                                    geometric_augmentations=[flip_aug, rot_aug], augmentation_ratio=0.2)

val_datagen = DataGeneratorTissue(path, "val", batch_size,
                                  patch_size, 3, nb_channels_out)

opt = keras.optimizers.Adam(lr)
model.compile(optimizer=opt, loss=jaccard_loss)

model_log_file_path = os.path.join(model_dir, "log.csv")
best_model_weights_file_path = os.path.join(model_dir, "best_model_weights.weights.h5")

callbacks = [
    keras.callbacks.CSVLogger(model_log_file_path),
    keras.callbacks.ModelCheckpoint(best_model_weights_file_path,
                                    save_best_only=True, save_weights_only=True)]
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 128, 128,  │        872 │ input_layer[0][0] │
# │ (Sequential)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64, 8) │          0 │ sequential[0][0]  │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 64, 64,    │      3,616 │ max_pooling2d[0]… │
# │ (Sequential)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ sequential_1[0][… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 32, 32,    │     14,144 │ max_pooling2d_1[… │
# │ (Sequential)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ sequential_2[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_3        │ (None, 16, 16,    │     55,936 │ max_pooling2d_2[… │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 64)  │          0 │ sequential_3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_4        │ (None, 8, 8, 128) │    222,464 │ max_pooling2d_3[… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_5        │ (None, 16, 16,    │     33,088 │ sequential_4[0][… │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ sequential_5[0][… │
# │ (Concatenate)       │ 128)              │            │ sequential_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_6        │ (None, 16, 16,    │    111,232 │ concatenate[0][0] │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_7        │ (None, 32, 32,    │      8,352 │ sequential_6[0][… │
# │ (Sequential)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ sequential_7[0][… │
# │ (Concatenate)       │ 64)               │            │ sequential_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_8        │ (None, 32, 32,    │     27,968 │ concatenate_1[0]… │
# │ (Sequential)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_9        │ (None, 64, 64,    │      2,128 │ sequential_8[0][… │
# │ (Sequential)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ sequential_9[0][… │
# │ (Concatenate)       │ 32)               │            │ sequential_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_10       │ (None, 64, 64,    │      7,072 │ concatenate_2[0]… │
# │ (Sequential)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_11       │ (None, 128, 128,  │        552 │ sequential_10[0]… │
# │ (Sequential)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ sequential_11[0]… │
# │ (Concatenate)       │ 16)               │            │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_12       │ (None, 128, 128,  │      1,808 │ concatenate_3[0]… │
# │ (Sequential)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_13       │ (None, 128, 128,  │        154 │ sequential_12[0]… │
# │ (Sequential)        │ 2)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 489,386 (1.87 MB)
#  Trainable params: 487,670 (1.86 MB)
#  Non-trainable params: 1,716 (6.70 KB)

# %%
model.fit(train_datagen,
          epochs=nb_epochs,
          validation_data=val_datagen,
          verbose=1,
          callbacks=callbacks)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 29s 228ms/step - loss: 0.6288 - val_loss: 0.8334
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.4503 - val_loss: 0.8101
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.4215 - val_loss: 0.5813
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.3957 - val_loss: 0.4879
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.3753 - val_loss: 0.4624
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.3747 - val_loss: 0.4799
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.3592 - val_loss: 0.4624
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.3564 - val_loss: 0.5113
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.3398 - val_loss: 0.4673
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.3307 - val_loss: 0.4541
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.3198 - val_loss: 0.4086
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.3220 - val_loss: 0.3858
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.2969 - val_loss: 0.3656
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.3027 - val_loss: 0.3216
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.3058 - val_loss: 0.2821
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2855 - val_loss: 0.3205
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.2799 - val_loss: 0.2747
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.2892 - val_loss: 0.2771
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2717 - val_loss: 0.2752
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.2571 - val_loss: 0.2494
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2842 - val_loss: 0.2736
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.2675 - val_loss: 0.3283
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.2624 - val_loss: 0.2446
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2539 - val_loss: 0.2728
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.2674 - val_loss: 0.3435
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2691 - val_loss: 0.2905
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2422 - val_loss: 0.2816
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2512 - val_loss: 0.2641
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2406 - val_loss: 0.2682
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2326 - val_loss: 0.2637
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.2295 - val_loss: 0.2565
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.2347 - val_loss: 0.2572
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.2433 - val_loss: 0.2526
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2338 - val_loss: 0.3394
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.2170 - val_loss: 0.2993
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.2103 - val_loss: 0.2404
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2240 - val_loss: 0.4615
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.2212 - val_loss: 0.2129
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2149 - val_loss: 0.2140
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.2164 - val_loss: 0.2321
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.2277 - val_loss: 0.2103
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2111 - val_loss: 0.7118
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1955 - val_loss: 0.7012
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.2030 - val_loss: 0.6281
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.2096 - val_loss: 0.2311
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.2081 - val_loss: 0.2192
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.2122 - val_loss: 0.1954
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.1818 - val_loss: 0.2121
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.2034 - val_loss: 0.2024
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.2008 - val_loss: 0.2172

# %% [markdown]
# # Model's training summary
#
# Plot the training and validation loss.
# Nothing to implement.

# %%
df = pd.read_csv(model_log_file_path, sep=",")
plt.plot(df["epoch"], df["loss"], "r", label="training loss")
plt.plot(df["epoch"], df["val_loss"], "b", label="validation loss")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()

# %% [markdown]
# # Model's inference function
#
# *make_apply_unet_model* is the function to call to embeds a UNet model into a function in charge of the whole pipeline to get from an 8-bit image an 8-bit binary segmentation mask.
# Implement the *apply_unet_model* function.
# Here the pipeline should include:
# * a [0,1]-normalization
# * a padding of the image (so that its dimension are 2^{unet_depth = len(unet_filters)-1} divisible)
# * the application of the UNet model
# * an unpadding of the UNet model's output (to retrieve the initial image dimensions)
# * the conversion of the UNet model's output into a binary segmentation mask by taking the label with the highest probability for each pixel
#
# The *pad_image* and *unpad_image* are already provided.

# %%
def pad_image(image, unet_depth):
    shape = image.shape[:2]
    if shape[0]%2**unet_depth != 0 or shape[1]%2**unet_depth != 0:
        new_shape = [shape[0] + 2**unet_depth - shape[0]%2**unet_depth,
                     shape[1] + 2**unet_depth - shape[1]%2**unet_depth]
        new_image = np.empty([*new_shape, 3])
        new_image[0:shape[0], 0:shape[1], :] = image[...]

        new_image[0:shape[0],shape[1]:new_shape[1],:] = image[:,shape[1]-(new_shape[1]-shape[1]):shape[1],:]
        new_image[shape[0]:new_shape[0],0:shape[1],:] = image[shape[0]-(new_shape[0]-shape[0]):shape[0],:,:]
        new_image[shape[0]:new_shape[0],shape[1]:new_shape[1],:] = image[shape[0]-(new_shape[0]-shape[0]):shape[0],shape[1]-(new_shape[1]-shape[1]):shape[1],:]

        return new_image
    else:
        return image

def unpad_image(image, old_shape):
    im_shape = image.shape[:2]
    if im_shape[0] == old_shape[0] and im_shape[1] == old_shape[1]:
        return image
    else:
        new_image = image[0:old_shape[0], 0:old_shape[1]]
        return new_image

def apply_unet_model(unet_model, unet_depth, image):

    ### TO BE IMPLEMENTED ###
    # Normalize image to [0,1]
    image_norm = image.astype(np.float32) / 255.0

    # Pad image to size divisible by 2**unet_depth
    padded_image = pad_image(image_norm, unet_depth)

    # Add batch and predict
    input_tensor = np.expand_dims(padded_image, axis=0)
    preds = unet_model.predict(input_tensor)

    # Remove batch dimension
    preds = np.squeeze(preds, axis=0)

    # Unpad to original image size
    preds_unpadded = unpad_image(preds, image.shape[:2])

    # Convert to binary mask by taking argmax along channel axis
    segm_binary = np.argmax(preds_unpadded, axis=-1)

    #########################
    return segm_binary

def make_apply_unet_model(unet_model, unet_depth):
    return lambda image: apply_unet_model(unet_model, unet_depth, image)

# %% [markdown]
# # Model's application on test dataset
#
# Apply a UNet model on test dataset images.
# The model is chosen with its id.

# %%
indexes_to_test = [8, 42, 10, 17, 35]  # indexes in [0, 42]

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

model_idx = -1

models_list = sorted(os.listdir("models"))
model_dir = os.path.join("models", models_list[model_idx])

with open(os.path.join(model_dir, "model_parameters.json"), "r") as model_parameters_file:
    model_parameters = json.load(model_parameters_file)

weights_path = os.path.join(model_dir, "best_model_weights.weights.h5")

model2 = build_unet_model(model_parameters["nb_channels_in"],
                          model_parameters["nb_channels_out"],
                          model_parameters["unet_filters"],
                          model_parameters["last_activation"])

model2.load_weights(weights_path)

apply_model =  make_apply_unet_model(model2, len(model_parameters["unet_filters"])-1)

test_images_dir = os.path.join(path, "test")
test_images_filenames = os.listdir(os.path.join(test_images_dir, "jpg"))

for test_image_idx in indexes_to_test:

  image = imageio.imread(os.path.join(*[test_images_dir, "jpg", test_images_filenames[test_image_idx]]))
  label = imageio.imread(os.path.join(*[test_images_dir, "lbl", test_images_filenames[test_image_idx]]))

  segm = apply_model(image)

  fig, ax = plt.subplots(1, 3, figsize=(18, 18))

  ax[0].imshow(image)
  ax[0].set_title("Input")
  ax[1].imshow(segm, cmap="gray")
  ax[1].set_title("Prediction")
  ax[2].imshow(label, cmap="gray")
  ax[2].set_title("Target")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %% [markdown]
# # Interpretation
#
# Change values of indexes to test with different images.
#
# What do you think about the results? What seems to work? What limitations do you see?
#
# **Answer:** The strong decrease in loss and clear mask outputs shows that this design works well for segmenting biomedical tissues.
#
# While the model usually gives good predictions, it does have some issues. Its performance drops when dealing with images that have unclear or weak boundaries, noisy backgrounds, or uncommon structures. This can lead to some missegmented areas or unclear edges in the prediction masks.
#
# Using geometric data augmentation techniques, like flips and rotations, makes the model more adaptable to changes in orientation and shape. However, it might still struggle with tough cases if the data is very challenging.
#
# Overall, UNet offers high accuracy in segmentation and is a reliable choice for this type of pixelwise annotation. We could improve results further by increasing the diversity of the data, using more advanced augmentation methods, or adding ways to measure uncertainty for difficult examples.
